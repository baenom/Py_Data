# %% [markdown]
# ## 판다스의 통계 함수

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/sehakflower/data/main/titanic.csv'
t_df = pd.read_csv(url,sep='\t')

# %% [markdown]
# #### 데이터의 통계치 확인하기

# %%
t_df.describe #통계치 확인
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# #### sum 함수

# %%
t_df.sum()
# Out:
# PassengerId                                                12246
# Survived                                                      54
# Pclass                                                       378
# Name           Braund, Mr. Owen HarrisCumings, Mrs. John Brad...
# Sex            malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                      3545.83
# SibSp                                                         96
# Parch                                                         62
# Ticket         A/5 21171PC 17599STON/O2. 31012821138033734503...
# Fare                                                   4385.0956
# Cabin          C85C123E46G6C103D56A6C23 C25 C27B78D33B30C52B2...
# Embarked       SCSSSQSSSCSSSSSSQSSCSSQSSSCSQSCCQSCSCSSCSSCCQS...
# dtype: object

# %% [markdown]
# #### count 함수

# %%
t_df.count()
# Out:
# PassengerId    156
# Survived       156
# Pclass         156
# Name           156
# Sex            156
# Age            126
# SibSp          156
# Parch          156
# Ticket         156
# Fare           156
# Cabin           31
# Embarked       155
# dtype: int64

# %% [markdown]
# #### max 함수

# %%
t_df.max()
# Out:
# PassengerId                                156
# Survived                                     1
# Pclass                                       3
# Name           van Billiard, Mr. Austin Blyler
# Sex                                       male
# Age                                       71.0
# SibSp                                        5
# Parch                                        5
# Ticket                             W.E.P. 5734
# Fare                                     263.0
# Cabin                                       G6
# Embarked                                     S
# dtype: object

# %% [markdown]
# #### min 함수

# %%
t_df.min()
# Out:
# PassengerId                                                 1
# Survived                                                    0
# Pclass                                                      1
# Name           Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Sex                                                    female
# Age                                                      0.83
# SibSp                                                       0
# Parch                                                       0
# Ticket                                                 110465
# Fare                                                     6.75
# Cabin                                                      A5
# Embarked                                                    C
# dtype: object

# %% [markdown]
# #### mean 함수

# %%
t_df.mean(numeric_only=True)
# Out:
# PassengerId    78.500000
# Survived        0.346154
# Pclass          2.423077
# Age            28.141508
# SibSp           0.615385
# Parch           0.397436
# Fare           28.109587
# dtype: float64

# %% [markdown]
# #### median 함수

# %%
t_df.median(numeric_only=True)
# Out:
# PassengerId    78.5000
# Survived        0.0000
# Pclass          3.0000
# Age            26.0000
# SibSp           0.0000
# Parch           0.0000
# Fare           14.4542
# dtype: float64

# %% [markdown]
# #### mode 함수

# %%
t_df.mode()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0     3.0
# 1              2       NaN     NaN
# 2              3       NaN     NaN
# 3              4       NaN     NaN
# 4              5       NaN     NaN
# ..           ...       ...     ...
# 151          152       NaN     NaN
# 152          153       NaN     NaN
# 153          154       NaN     NaN
# 154          155       NaN     NaN
# 155          156       NaN     NaN
#
#                                                Name   Sex   Age  SibSp  Parch  \
# 0    Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  male  21.0    0.0    0.0
# 1                          Allen, Mr. William Henry   NaN   NaN    NaN    NaN
# 2                 Andersson, Miss. Ellis Anna Maria   NaN   NaN    NaN    NaN
# 3                   Andersson, Miss. Erna Alexandra   NaN   NaN    NaN    NaN
# 4                       Andersson, Mr. Anders Johan   NaN   NaN    NaN    NaN
# ...

# %% [markdown]
# #### mad 함수

# %%
t_df.mad()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 t_df.mad()
#
# File c:\Users\user\anaconda3\envs\pydata26\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'mad'

# %%
num_t_df = t_df.select_dtypes(include='number')
mad = (num_t_df - num_t_df.mean()).abs().mean()
print(mad)
# Out:
# PassengerId    39.000000
# Survived        0.452663
# Pclass          0.710059
# Age            11.142858
# SibSp           0.773176
# Parch           0.616535
# Fare           22.619713
# dtype: float64

# %% [markdown]
# #### var 함수

# %%
t_df.var(numeric_only=True)
# Out:
# PassengerId    2041.000000
# Survived          0.227792
# Pclass            0.632754
# Age             213.565487
# SibSp             1.115633
# Parch             0.757155
# Fare           1552.442481
# dtype: float64

# %% [markdown]
# #### std 함수

# %%
t_df.std(numeric_only=True)
# Out:
# PassengerId    45.177428
# Survived        0.477275
# Pclass          0.795459
# Age            14.613880
# SibSp           1.056235
# Parch           0.870146
# Fare           39.401047
# dtype: float64

# %% [markdown]
# #### skew 함수

# %%
t_df.skew(numeric_only=True)
# Out:
# PassengerId    0.000000
# Survived       0.653058
# Pclass        -0.912744
# Age            0.700367
# SibSp          2.220685
# Parch          2.760421
# Fare           4.176408
# dtype: float64

# %% [markdown]
# #### kurt 함수

# %%
t_df.kurt(numeric_only=True)
# Out:
# PassengerId    -1.200000
# Survived       -1.594120
# Pclass         -0.803872
# Age             0.613747
# SibSp           4.996881
# Parch           9.346662
# Fare           21.109985
# dtype: float64
